# %%
# Remove the old folder if it exists
import shutil
import os

repo_dir = "End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection"
if os.path.exists(repo_dir):
    shutil.rmtree(repo_dir)

# Clone only the `testing` branch
# !git clone --single-branch --branch testing https://github.com/mohamed-stifi/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection.git
# Out:
# Cloning into 'End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 106 (delta 26), reused 102 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (106/106), 88.19 KiB | 12.60 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
import os
os.chdir('End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection')

# %%
# !pip install -r requirements.txt

# %%
# !pwd
# Out:
# /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection

# %%
from text_classifier.pipeline.stage_01_data_ingestion import DataIngestionPipeline
from text_classifier.pipeline.stage_02_data_validation import DataValidationPipeline
from text_classifier.pipeline.stage_03_data_transformation import DataTransformationPipeline
from text_classifier.pipeline.stage_04_model_trainer import ModelTrainingPipeline
from text_classifier.pipeline.stage_05_model_evaluation import ModelEvaluationPipeline
from text_classifier.pipeline.stage_06_hyperparameter_optimization import HyperparameterOptimizationPipeline
from text_classifier.pipeline.stage_07_update_parameters import UpdateParametersPipeline
# Out:
# /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection

# %% [markdown]
# ## DataIngestionPipeline

# %%
data_ingestion_pipeline = DataIngestionPipeline()

# %%
data_ingestion_pipeline.main()

# %%
# !ls artifacts/data_ingestion
# Out:
# data.zip  extracted_data

# %% [markdown]
# ## DataValidationPipeline

# %%
data_validation_pipeline = DataValidationPipeline()

# %%
data_validation_pipeline.main()

# %%
# !ls artifacts/data_validation
# Out:
# status.txt

# %% [markdown]
# ## DataTransformationPipeline

# %%
data_transformation_pipeline = DataTransformationPipeline()

# %%
data_transformation_pipeline.main()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Processing Batches: 100%|██████████| 1/1 [00:21<00:00, 21.55s/it]

# %%
# !ls artifacts/data_transformation
# Out:
# test.csv	   tokenizer  train_encodings.pt  val_encodings.pt
# test_encodings.pt  train.csv  val.csv

# %% [markdown]
# ## ModelTrainingPipeline

# %%
model_training_pipeline = ModelTrainingPipeline()

# %%
model_training_pipeline.main()
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# path
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection/artifacts/model_trainer/lstm exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name       | Type             | Params | Mode
# --------------------------------------------------------
# 0 | embedding  | Embedding        | 216 K  | train
# 1 | lstm       | LSTM             | 2.4 M  | train
# ...

# %%
# !ls artifacts/model_trainer
# Out:
# bert  lstm  model_comparison.json  roberta

# %% [markdown]
# ## ModelEvaluationPipeline

# %%
model_evaluation_pipeline = ModelEvaluationPipeline()

# %%
model_evaluation_pipeline.main()
# Out:
# path
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# !ls artifacts/model_evaluation
# Out:
# bert_confusion_matrix.png  model_comparison.png
# evaluation_report.json	   roberta_confusion_matrix.png
# lstm_confusion_matrix.png

# %% [markdown]
# ## HyperparameterOptimizationPipeline

# %%
hyperparameter_optimization_pipeline = HyperparameterOptimizationPipeline()

# %%
hyperparameter_optimization_pipeline.main()
# Out:
# /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection/src/text_classifier/components/hyperparameter_optimizer.py:237: ExperimentalWarning: MLflowCallback is experimental (supported from v1.4.0). The interface can change in the future.
#   mlflow_optuna_callback = optuna.integration.MLflowCallback(
# [I 2025-06-01 03:36:22,083] A new study created in memory with name: text_classifier_hpo_lstm_data_transformation
# {'learning_rate': {'type': 'float', 'low': 0.0001, 'high': 0.01, 'log': True}, 'embedding_dim': {'type': 'categorical', 'choices': [64, 128, 256]}, 'hidden_dim': {'type': 'categorical', 'choices': [128, 256, 512]}, 'num_layers': {'type': 'int', 'low': 1, 'high': 3}, 'dropout': {'type': 'float', 'low': 0.1, 'high': 0.5}}
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# ...

# %%
# !ls artifacts/hyperparameter_optimization/
# Out:
# hpo_optimization_summary.json

# %%
# !zip mlruns.zip -r mlruns

# %% [markdown]
# ## UpdateParametersPipeline

# %%
update_parameters_pipeline = UpdateParametersPipeline()

# %%
update_parameters_pipeline.main()

# %% [markdown]
# ## Test main

# %%
# !python main.py
# Out:
# /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection
# [2025-06-01 04:06:35,446: INFO: utils: numexpr.utils: NumExpr defaulting to 2 threads.]
# [2025-06-01 04:06:50,347: INFO: main: textClassifierLogger: Starting full MLOps pipeline execution (including HPO and param update)...]
# [2025-06-01 04:06:50,347: INFO: main: textClassifierLogger: --- Running stage: DataIngestionPipeline ---]
# [2025-06-01 04:06:50,347: INFO: stage_01_data_ingestion: textClassifierLogger: >>>>>> Stage: Data Ingestion Stage started <<<<<<]
# [2025-06-01 04:06:50,350: INFO: common: text_classifier.utils.common: yaml file: /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection/config/config.yaml loaded successfully]
# [2025-06-01 04:06:50,357: INFO: common: text_classifier.utils.common: yaml file: /content/End-to-End-MLOps-Pipeline-for-AI-Text-Generation-Detection/config/params.yaml loaded successfully]
# ...
